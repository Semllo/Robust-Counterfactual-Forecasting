# %% [markdown]
# #  DATOS DE TRAFICO
#
# - Eliminar distritos que no utilizo
# - Eliminar datos no validos

# %%
import pandas as pd

df_datos = pd.read_csv("datos/CONT_METEO_REDUCIDO_2021_2024.csv")

df_datos.drop(columns='Unnamed: 0', inplace=True)

df_datos
# Out:
#         ESTACION  DISTRITO           FECHA_HORA   NO   NO2   NOx  PM10  PM2_5  \
# 0              8         3  2021-01-01 01:00:00  4.0  23.0  28.0   8.0    7.0
# 1              8         3  2021-01-01 02:00:00  6.0  36.0  46.0  12.0   10.0
# 2              8         3  2021-01-01 03:00:00  2.0  19.0  22.0   5.0    4.0
# 3              8         3  2021-01-01 04:00:00  1.0  12.0  13.0   5.0    4.0
# 4              8         3  2021-01-01 05:00:00  1.0  12.0  13.0   1.0    1.0
# ...          ...       ...                  ...  ...   ...   ...   ...    ...
# 338953        60         8  2023-12-31 20:00:00  5.0  30.0  37.0   7.0    NaN
# 338954        60         8  2023-12-31 21:00:00  6.0  35.0  44.0   7.0    NaN
# 338955        60         8  2023-12-31 22:00:00  4.0  37.0  44.0  11.0    NaN
# 338956        60         8  2023-12-31 23:00:00  2.0  20.0  23.0   9.0    NaN
# 338957        60         8  2023-12-31 00:00:00  2.0  15.0  19.0  11.0    NaN
#
# ...

# %%
distritos_lista = df_datos['DISTRITO'].unique()
distritos_lista.sort()
distritos_lista
# Out:
# array([ 2,  3,  4,  5,  6,  8,  9, 11, 12, 14, 16, 18, 21])

# %%
# Lectura datos trafico

df = pd.read_csv("datos/trafico2021_2023.csv")

df
# Out:
#            Unnamed: 0    id                fecha tipo_elem  intensidad error
# 0                   0  1001  2021-01-01 00:00:00       M30         144     N
# 1                   1  1001  2021-01-01 00:15:00       M30          84     N
# 2                   2  1001  2021-01-01 00:30:00       M30         108     N
# 3                   3  1001  2021-01-01 00:45:00       M30         792     N
# 4                   4  1001  2021-01-01 01:00:00       M30        1704     N
# ...               ...   ...                  ...       ...         ...   ...
# 424107274   142128614  4744  2023-12-08 05:15:00       URB          51     N
# 424107275   142128615  4744  2023-12-08 05:30:00       URB          64     N
# 424107276   142128616  4744  2023-12-08 05:45:00       URB          48     N
# 424107277   142128617  4744  2023-12-08 06:00:00       URB          60     N
# 424107278   142128618  4744  2023-12-08 06:15:00       URB          48     N
#
# [424107279 rows x 6 columns]

# %% [markdown]
# Para poder eliminar los distritos, primero debo añadirselo por id, a partir del df de ubicaciones
#
# - PRIMERO VOY A LEER LOS IDS DE LAS UBICACIONES DONDE EL DISTRITO ESTÁ EN EL LISTADO ANTERIOR
# - DESPUES OBTENER UNA LISTA DE IDS
# - CON ESA LISTA DE IDS ELIMINAR LOS QUE NO ESTEN EN EL DF TRAFICO Y SOBREESCRIBIRLO

# %% [markdown]
# ### UBICACIONES

# %%
df_ubicaciones = pd.read_csv("datos/ubicaciones_sensores_trafico.csv")
df_ubicaciones
# Out:
#       Unnamed: 0 tipo_elem  distrito     id cod_cent  \
# 0              0       URB       4.0   3840    01001
# 1              1       URB       4.0   3841    01002
# 2              2       URB       1.0   3842    01003
# 3              3       URB       4.0   3843    01004
# 4              4       URB       4.0   3844    01005
# ...          ...       ...       ...    ...      ...
# 5423        5423       URB      16.0  11235    72406
# 5424        5424       URB      16.0  11276    72407
# 5425        5425       URB      16.0  11277    72408
# 5426        5426       URB      16.0  11279    72409
# 5427        5427       URB      16.0  11278    72410
#
#                                                  nombre                utm_x  \
# 0      Jose Ortega y Gasset E-O - Pº Castellana-Serrano     441615.343346657
# 1      Jose Ortega y Gasset O-E - Serrano-Pº Castellana     441705.882339595
# 2                     Pº Recoletos N-S - Almirante-Prim     441319.371258338
# ...

# %%
df_ubicaciones = df_ubicaciones[df_ubicaciones['distrito'].isin(distritos_lista)]
df_ubicaciones
# Out:
#       Unnamed: 0 tipo_elem  distrito     id cod_cent  \
# 0              0       URB       4.0   3840    01001
# 1              1       URB       4.0   3841    01002
# 3              3       URB       4.0   3843    01004
# 4              4       URB       4.0   3844    01005
# 5              5       URB       4.0   3845    01006
# ...          ...       ...       ...    ...      ...
# 5423        5423       URB      16.0  11235    72406
# 5424        5424       URB      16.0  11276    72407
# 5425        5425       URB      16.0  11277    72408
# 5426        5426       URB      16.0  11279    72409
# 5427        5427       URB      16.0  11278    72410
#
#                                                  nombre                utm_x  \
# 0      Jose Ortega y Gasset E-O - Pº Castellana-Serrano     441615.343346657
# 1      Jose Ortega y Gasset O-E - Serrano-Pº Castellana     441705.882339595
# 3             Pº Recoletos S-N - Pl. Cibeles- Recoletos      441301.63298559
# ...

# %% [markdown]
# De 5500 Paso a 3600

# %%
ids_lista = df_ubicaciones['id'].unique()
ids_lista.sort()
len(ids_lista)
# Out:
# 3260

# %% [markdown]
# ### Eliminar ids no presentes en el df trafico

# %%
df = df[df['id'].isin(ids_lista)]
df
# Out:
#            Unnamed: 0    id                fecha tipo_elem  intensidad error
# 11892           11892  1009  2021-01-01 00:00:00       M30         180     N
# 11893           11893  1009  2021-01-01 00:15:00       M30         108     N
# 11894           11894  1009  2021-01-01 00:30:00       M30         108     N
# 11895           11895  1009  2021-01-01 00:45:00       M30         672     N
# 11896           11896  1009  2021-01-01 01:00:00       M30        1452     N
# ...               ...   ...                  ...       ...         ...   ...
# 424091712   142113052  4738  2023-12-31 22:45:00       URB          20     N
# 424091713   142113053  4738  2023-12-31 23:00:00       URB          30     N
# 424091714   142113054  4738  2023-12-31 23:15:00       URB          20     N
# 424091715   142113055  4738  2023-12-31 23:30:00       URB          22     N
# 424091716   142113056  4738  2023-12-31 23:45:00       URB          12     N
#
# [276996275 rows x 6 columns]

# %%
len(df['id'].unique())
# Out:
# 3135

# %% [markdown]
# De 424.107.279 filas paso a 276.996.275

# %%
# Sobreescribir

df = df.drop('Unnamed: 0', axis=1)

df.to_csv("datos/trafico2021_2023.csv")

# %% [markdown]
# De 18 GB paso a 12 GB
